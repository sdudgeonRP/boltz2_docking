# %%
# !pip install biopython
# Out:
# Requirement already satisfied: biopython in /opt/saturncloud/envs/saturn/lib/python3.11/site-packages (1.84)
# Requirement already satisfied: numpy in /opt/saturncloud/envs/saturn/lib/python3.11/site-packages (from biopython) (1.26.4)

# %%
import os
import pandas as pd
from Bio.PDB import MMCIFParser
from math import sqrt
import itertools
import json

# %%
def calculate_distance(atom1, atom2):
    diff = atom1.coord - atom2.coord
    return sqrt((diff ** 2).sum())

# %%
def get_distances(chain_A, chain_B, dock_label):
    distances = []
    for atom_A, atom_B in itertools.product(chain_A.get_atoms(), chain_B.get_atoms()):
        dist = calculate_distance(atom_A, atom_B)
        distances.append({
            "atom1_name": atom_A.get_name(),             # Atom name, e.g., "CG2"
            "atom1_residue": atom_A.get_parent().get_resname(),  # Residue name, e.g., "LEU"
            "atom1_residue_num": atom_A.get_parent().get_id()[1],    # Residue sequence number (e.g., 132)
            "atom1_insertion_code": atom_A.get_parent().get_id()[2],    # Insertion code, if present
            "atom1_chain_id": atom_A.get_parent().get_parent().id,  # Chain ID, e.g., "F1"
            "atom2_name": atom_B.get_name(),             # Atom name, e.g., "CG2"
            "atom2_residue": atom_B.get_parent().get_resname(),  # Residue name, e.g., "LEU"
            "atom2_residue_num": atom_B.get_parent().get_id()[1],    # Residue sequence number (e.g., 132)
            "atom2_insertion_code": atom_B.get_parent().get_id()[2],    # Insertion code, if present
            "atom2_chain_id": atom_B.get_parent().get_parent().id,  # Chain ID, e.g., "F1"
            "distance": dist,
            "dock": dock_label
        })
    return sorted(distances, key=lambda x: x["distance"])  # return top 10

# %%
# --- Folder structure ---
base_folder = "boltz_results_safusidenib/predictions"

# --- MMCIF parser ---
parser = MMCIFParser(QUIET=True)

# --- Collect all distance entries ---
all_distances = []
all_affinities = []
all_confidences = []

# --- Traverse subfolders ---
for subfolder in os.listdir(base_folder):
    subfolder_path = os.path.join(base_folder, subfolder)
    if os.path.isdir(subfolder_path):
        # Find the .cif file in the subfolder
        cif_files = [f for f in os.listdir(subfolder_path) if f.endswith(".cif")]
        if not cif_files:
            print(f"No .cif file in {subfolder_path}")
            continue

        cif_path = os.path.join(subfolder_path, cif_files[0])
        try:
            structure = parser.get_structure(subfolder, cif_path)
            model = structure[0]
            chains = list(model.get_chains())

            if len(chains) < 2:
                print(f"Skipping {subfolder}: fewer than 3 chains found")
                continue

            protein_1 = chains[0]
            protein_2 = chains[1]
            protein_3 = chains[2]
            protein_4 = chains[3]
            protein_5 = chains[4]
            protein_6 = chains[5]
            drug = chains[6]

            # Compute and collect distances
            all_distances.extend(get_distances(protein_1, drug, subfolder))
            all_distances.extend(get_distances(protein_2, drug, subfolder))
            all_distances.extend(get_distances(protein_3, drug, subfolder))
            all_distances.extend(get_distances(protein_4, drug, subfolder))
            all_distances.extend(get_distances(protein_5, drug, subfolder))
            all_distances.extend(get_distances(protein_6, drug, subfolder))

        except Exception as e:
            print(f"Error processing {cif_path}: {e}")

        affinity_files = [f for f in os.listdir(subfolder_path) if f.startswith("affinity_")]

        if not affinity_files:
            print(f"No affinity file in {subfolder_path}")
            continue

        affinity_path = os.path.join(subfolder_path, affinity_files[0])

        affinity = None
        with open(affinity_path) as affinity_file:
            affinity = json.load(affinity_file)

        if affinity is not None:
            affinity["dock"] = subfolder
            all_affinities.extend([affinity])

        confidence_files = [f for f in os.listdir(subfolder_path) if f.startswith("confidence_")]

        if not confidence_files:
            print(f"No confidence file in {subfolder_path}")
            continue

        confidence_path = os.path.join(subfolder_path, confidence_files[0])

        confidence = None
        with open(confidence_path) as confidence_file:
            confidence = json.load(confidence_file)

        if confidence is not None:
            confidence["dock"] = subfolder
            all_confidences.extend([confidence])


# --- Convert to DataFrame ---
distance_df = pd.DataFrame(all_distances)
affinity_df = pd.DataFrame(all_affinities)
confidence_df = pd.DataFrame(all_confidences)
# Out:
# Error processing boltz_results_safusidenib/predictions/safu_SMO/safu_SMO_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_SMO
# Error processing boltz_results_safusidenib/predictions/safu_IL6RA/safu_IL6RA_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_IL6RA
# No affinity file in boltz_results_safusidenib/predictions/safu_COX2
# Error processing boltz_results_safusidenib/predictions/safu_TGFBR2/safu_TGFBR2_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_TGFBR2
# Error processing boltz_results_safusidenib/predictions/safu_SOX9/safu_SOX9_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_SOX9
# Error processing boltz_results_safusidenib/predictions/safu_CCR2/safu_CCR2_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_CCR2
# Error processing boltz_results_safusidenib/predictions/safu_ADAMTS5/safu_ADAMTS5_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_ADAMTS5
# Error processing boltz_results_safusidenib/predictions/safu_MITF/safu_MITF_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_MITF
# Error processing boltz_results_safusidenib/predictions/safu_JAK1/safu_JAK1_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_JAK1
# Error processing boltz_results_safusidenib/predictions/safu_MMP13/safu_MMP13_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_MMP13
# Error processing boltz_results_safusidenib/predictions/safu_CTNNB1/safu_CTNNB1_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_CTNNB1
# Error processing boltz_results_safusidenib/predictions/safu_MC1R/safu_MC1R_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_MC1R
# Error processing boltz_results_safusidenib/predictions/safu_LGR5/safu_LGR5_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_LGR5
# Error processing boltz_results_safusidenib/predictions/safu_NTRK1/safu_NTRK1_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_NTRK1
# Error processing boltz_results_safusidenib/predictions/safu_NGF/safu_NGF_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_NGF
# Error processing boltz_results_safusidenib/predictions/safu_TYRP1/safu_TYRP1_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_TYRP1
# Error processing boltz_results_safusidenib/predictions/safu_FGFR2/safu_FGFR2_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_FGFR2
# Error processing boltz_results_safusidenib/predictions/safu_P2X3/safu_P2X3_model_0.cif: list index out of range
# No affinity file in boltz_results_safusidenib/predictions/safu_P2X3

# %%
distance_df_condensed = distance_df.groupby('dock').apply(lambda g: pd.Series({
    'percent_hit': 100 * (((g['atom1_residue_num'].between(61, 69) | g['atom1_residue_num'].between(79, 115)) & (g['distance'] < 4)).sum() / len(g))
})).reset_index()

#result_df = distance_df_condensed.merge(affinity_df, on='dock').merge(confidence_df, on='dock')
#result_df[['company', 'patent_ref_number', 'dimer']] = result_df['dock'].str.split('_', expand=True)
# Out:
# /tmp/ipykernel_14638/3799544491.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   distance_df_condensed = distance_df.groupby('dock').apply(lambda g: pd.Series({

# %%
distance_df.to_csv('distance_df_kai.csv')
distance_df_condensed.to_csv('distance_df_condensed_kai.csv')
confidence_df.to_csv('confidence_df_kai.csv')
